# %%
GITHUB_USERNAME = "theo4850"
REPO_NAME = "Signal-Analysis"

# %%
repo_url = f"https://github.com/{GITHUB_USERNAME}/{REPO_NAME}.git"
# !git clone {repo_url}
# Out:
# Cloning into 'Signal-Analysis'...
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 9 (delta 1), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (9/9), done.
# Resolving deltas: 100% (1/1), done.

# %%
# %cd /content/Signal-Analysis
# !ls
# Out:
# /content/Signal-Analysis
# README.md

# %%
# !mkdir -p notebooks
# !mkdir -p src
# !mkdir -p data
# !mkdir -p results/figures
# !mkdir -p results/metrics
# !touch data/.gitkeep

# %%
# !find . -maxdepth 3 -type d | sort
# Out:
# .
# ./data
# ./.git
# ./.git/branches
# ./.git/hooks
# ./.git/info
# ./.git/logs
# ./.git/logs/refs
# ./.git/objects
# ./.git/objects/info
# ./.git/objects/pack
# ./.git/refs
# ./.git/refs/heads
# ./.git/refs/remotes
# ./.git/refs/tags
# ./notebooks
# ./results
# ./results/figures
# ./results/metrics
# ./src
